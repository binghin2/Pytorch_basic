# %%
import torch

# %%
# 간단한 선형 회귀 예제로 그래디언트 디센트 구현
torch.manual_seed(42)

# 데이터 생성
X = torch.randn(100, 1)
y = 3 * X + 2 + torch.randn(100, 1) * 0.1

# 파라미터 초기화
w = torch.randn(1, 1, requires_grad=True)
b = torch.randn(1, requires_grad=True)

# 하이퍼파라미터
learning_rate = 0.01
epochs = 100

# 그래디언트 디센트
losses = []
for epoch in range(epochs):
    # Forward pass
    y_pred = X @ w + b
    loss = torch.mean((y_pred - y) ** 2)
    losses.append(loss.item())
    
    # Backward pass
    loss.backward()
    
    # 파라미터 업데이트
    with torch.no_grad():
        w -= learning_rate * w.grad
        b -= learning_rate * b.grad
        w.grad.zero_()
        b.grad.zero_()
    
    if (epoch + 1) % 20 == 0:
        print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}")

print(f"\nLearned w: {w.item():.4f}, b: {b.item():.4f}")
# Out:
# Epoch 20/100, Loss: 5.4908
# Epoch 40/100, Loss: 2.3738
# Epoch 60/100, Loss: 1.0293
# Epoch 80/100, Loss: 0.4490
# Epoch 100/100, Loss: 0.1985
#
# Learned w: 2.6656, b: 1.7509

# %%
print('hello world')
# Out:
# hello world
